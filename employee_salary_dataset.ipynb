# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("1-employee_salary_dataset.csv")
orgdata=data

# %%
data.head()
# Out:
#   Employee_ID   Age  Gender Education  Experience_Years  Department Job_Level  \
# 0    EMP10001  28.0    Male    Master               6.0  Operations    Junior
# 1    EMP10002  26.0  Female  Bachelor               5.0  Operations    Junior
# 2    EMP10003  31.0  Female  Bachelor               5.0   Marketing    Junior
# 3    EMP10004  59.0  Female  Bachelor              29.0       Sales      Lead
# 4    EMP10005  23.0  Female  Bachelor               0.0       Sales    Junior
#
#    Performance_Rating  Certifications  Overtime_Hours Remote_Work       City  \
# 0                   1               4              15         Yes    Chennai
# 1                   2               3              32          No      Delhi
# 2                   4               5              17         Yes  Hyderabad
# 3                   3               0              46          No     Mumbai
# 4                   2               4               5         Yes  Hyderabad
#
# ...

# %%
data.tail()
# Out:
#      Employee_ID   Age  Gender Education  Experience_Years  Department  \
# 5015    EMP13816  25.0  Female       PhD               4.0  Operations
# 5016    EMP13817  21.0    Male  Bachelor               0.0   Marketing
# 5017    EMP13818  60.0  Female    Master              25.0          IT
# 5018    EMP13819  32.0    Male   Diploma              10.0          HR
# 5019    EMP13820  33.0    Male  Bachelor               3.0   Marketing
#
#      Job_Level  Performance_Rating  Certifications  Overtime_Hours  \
# 5015    Junior                   3               6               1
# 5016    Junior                   1               3              19
# 5017      Lead                   4               8              51
# 5018       Mid                   2               5              12
# 5019    Junior                   1               5              46
#
#      Remote_Work       City  Company_Tenure  Projects_Completed  Skill_Score  \
# ...

# %%
data.head(5)
# Out:
#   Employee_ID   Age  Gender Education  Experience_Years  Department Job_Level  \
# 0    EMP10001  28.0    Male    Master               6.0  Operations    Junior
# 1    EMP10002  26.0  Female  Bachelor               5.0  Operations    Junior
# 2    EMP10003  31.0  Female  Bachelor               5.0   Marketing    Junior
# 3    EMP10004  59.0  Female  Bachelor              29.0       Sales      Lead
# 4    EMP10005  23.0  Female  Bachelor               0.0       Sales    Junior
#
#    Performance_Rating  Certifications  Overtime_Hours Remote_Work       City  \
# 0                   1               4              15         Yes    Chennai
# 1                   2               3              32          No      Delhi
# 2                   4               5              17         Yes  Hyderabad
# 3                   3               0              46          No     Mumbai
# 4                   2               4               5         Yes  Hyderabad
#
# ...

# %%
data.shape
# Out:
# (5020, 16)

# %%
data.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Education', 'Experience_Years',
#        'Department', 'Job_Level', 'Performance_Rating', 'Certifications',
#        'Overtime_Hours', 'Remote_Work', 'City', 'Company_Tenure',
#        'Projects_Completed', 'Skill_Score', 'Annual_Salary_LPA'],
#       dtype='str')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5020 entries, 0 to 5019
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee_ID         5020 non-null   str
#  1   Age                 4960 non-null   float64
#  2   Gender              5020 non-null   str
#  3   Education           5020 non-null   str
#  4   Experience_Years    4960 non-null   float64
#  5   Department          5020 non-null   str
#  6   Job_Level           5020 non-null   str
#  7   Performance_Rating  5020 non-null   int64
#  8   Certifications      5020 non-null   int64
#  9   Overtime_Hours      5020 non-null   int64
#  10  Remote_Work         5020 non-null   str
#  11  City                5020 non-null   str
#  12  Company_Tenure      5020 non-null   int64
#  13  Projects_Completed  5020 non-null   int64
#  14  Skill_Score         4960 non-null   float64
#  15  Annual_Salary_LPA   5020 non-null   float64
# ...

# %%
data.describe()
# Out:
#                Age  Experience_Years  Performance_Rating  Certifications  \
# count  4960.000000       4960.000000         5020.000000     5020.000000
# mean     40.468145         11.152419            3.034661        4.986255
# std      11.576821          7.724104            1.411955        3.159127
# min      14.000000          0.000000            1.000000        0.000000
# 25%      30.000000          5.000000            2.000000        2.000000
# 50%      41.000000         11.000000            3.000000        5.000000
# 75%      51.000000         17.000000            4.000000        8.000000
# max      90.000000         33.000000            5.000000       10.000000
#
#        Overtime_Hours  Company_Tenure  Projects_Completed  Skill_Score  \
# count     5020.000000     5020.000000         5020.000000  4960.000000
# mean        29.907968        5.500996           15.481076    74.922984
# std         17.710887        4.415711            8.691489    14.814703
# ...

# %%
data.dtypes
# Out:
# Employee_ID               str
# Age                   float64
# Gender                    str
# Education                 str
# Experience_Years      float64
# Department                str
# Job_Level                 str
# Performance_Rating      int64
# Certifications          int64
# Overtime_Hours          int64
# Remote_Work               str
# City                      str
# Company_Tenure          int64
# Projects_Completed      int64
# Skill_Score           float64
# Annual_Salary_LPA     float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Employee_ID            0
# Age                   60
# Gender                 0
# Education              0
# Experience_Years      60
# Department             0
# Job_Level              0
# Performance_Rating     0
# Certifications         0
# Overtime_Hours         0
# Remote_Work            0
# City                   0
# Company_Tenure         0
# Projects_Completed     0
# Skill_Score           60
# Annual_Salary_LPA      0
# dtype: int64

# %%
(data.isnull().sum()/len(data))*100
# Out:
# Employee_ID           0.000000
# Age                   1.195219
# Gender                0.000000
# Education             0.000000
# Experience_Years      1.195219
# Department            0.000000
# Job_Level             0.000000
# Performance_Rating    0.000000
# Certifications        0.000000
# Overtime_Hours        0.000000
# Remote_Work           0.000000
# City                  0.000000
# Company_Tenure        0.000000
# Projects_Completed    0.000000
# Skill_Score           1.195219
# Annual_Salary_LPA     0.000000
# dtype: float64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Employee_ID, Age, Gender, Education, Experience_Years, Department, Job_Level, Performance_Rating, Certifications, Overtime_Hours, Remote_Work, City, Company_Tenure, Projects_Completed, Skill_Score, Annual_Salary_LPA]
# Index: []

# %%
data.drop_duplicates()
# Out:
#      Employee_ID   Age  Gender Education  Experience_Years  Department  \
# 0       EMP10001  28.0    Male    Master               6.0  Operations
# 1       EMP10002  26.0  Female  Bachelor               5.0  Operations
# 2       EMP10003  31.0  Female  Bachelor               5.0   Marketing
# 3       EMP10004  59.0  Female  Bachelor              29.0       Sales
# 4       EMP10005  23.0  Female  Bachelor               0.0       Sales
# ...          ...   ...     ...       ...               ...         ...
# 5015    EMP13816  25.0  Female       PhD               4.0  Operations
# 5016    EMP13817  21.0    Male  Bachelor               0.0   Marketing
# 5017    EMP13818  60.0  Female    Master              25.0          IT
# 5018    EMP13819  32.0    Male   Diploma              10.0          HR
# 5019    EMP13820  33.0    Male  Bachelor               3.0   Marketing
#
#      Job_Level  Performance_Rating  Certifications  Overtime_Hours  \
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.drop("Employee_ID",axis=1,inplace=True)

# %%
numerical_cols=data.select_dtypes(include=['int64','float64']).columns
numerical_cols
# Out:
# Index(['Age', 'Experience_Years', 'Performance_Rating', 'Certifications',
#        'Overtime_Hours', 'Company_Tenure', 'Projects_Completed', 'Skill_Score',
#        'Annual_Salary_LPA'],
#       dtype='str')

# %%
categorical_cols=data.select_dtypes(include=['str']).columns
categorical_cols
# Out:
# Index(['Gender', 'Education', 'Department', 'Job_Level', 'Remote_Work',
#        'City'],
#       dtype='str')

# %%
for col in categorical_cols:
    print(col)
    print(data[col].unique())
    print("-"*50)
# Out:
# Gender
# <ArrowStringArray>
# ['Male', 'Female']
# Length: 2, dtype: str
# --------------------------------------------------
# Education
# <ArrowStringArray>
# ['Master', 'Bachelor', 'Diploma', 'PhD']
# Length: 4, dtype: str
# --------------------------------------------------
# Department
# <ArrowStringArray>
# ['Operations', 'Marketing', 'Sales', 'IT', 'HR']
# Length: 5, dtype: str
# --------------------------------------------------
# Job_Level
# <ArrowStringArray>
# ['Junior', 'Lead', 'Mid', 'Senior', 'Manager']
# Length: 5, dtype: str
# --------------------------------------------------
# Remote_Work
# <ArrowStringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
# --------------------------------------------------
# City
# <ArrowStringArray>
# ['Chennai', 'Delhi', 'Hyderabad', 'Mumbai']
# Length: 4, dtype: str
# --------------------------------------------------

# %%
data['Gender']=data['Gender'].replace({'male':'Male','FEMALE':'Female'})

# %%
data['Remote_Work']=data['Remote_Work'].replace({'YES':'Yes','no':'No'})

# %%
for col in ['Gender','Remote_Work']:
    print(data[col].unique())
# Out:
# <ArrowStringArray>
# ['Male', 'Female']
# Length: 2, dtype: str
# <ArrowStringArray>
# ['Yes', 'No']
# Length: 2, dtype: str

# %%
data[data['Age']<18]
# Out:
#        Age  Gender Education  Experience_Years Department Job_Level  \
# 536   15.0    Male  Bachelor              20.0         IT    Senior
# 1391  16.0    Male  Bachelor               0.0      Sales    Junior
# 1477  14.0  Female   Diploma               3.0  Marketing    Junior
#
#       Performance_Rating  Certifications  Overtime_Hours Remote_Work     City  \
# 536                    2               7              22         Yes   Mumbai
# 1391                   2               9              39         Yes  Chennai
# 1477                   5               6              10         Yes    Delhi
#
#       Company_Tenure  Projects_Completed  Skill_Score  Annual_Salary_LPA
# 536               13                  15         97.0              59.80
# 1391               0                  11         51.0              20.42
# 1477               3                  30         66.0              39.14

# %%
data[data['Age']>70]
# Out:
#        Age  Gender Education  Experience_Years  Department Job_Level  \
# 161   75.0    Male    Master              18.0  Operations    Senior
# 1485  80.0  Female  Bachelor               1.0   Marketing    Junior
# 1647  90.0  Female  Bachelor               8.0       Sales       Mid
#
#       Performance_Rating  Certifications  Overtime_Hours Remote_Work     City  \
# 161                    5               3              46          No   Mumbai
# 1485                   2               6              54         Yes    Delhi
# 1647                   4               0              16         Yes  Chennai
#
#       Company_Tenure  Projects_Completed  Skill_Score  Annual_Salary_LPA
# 161                1                  19         80.0              70.68
# 1485               1                   1         63.0              23.14
# 1647               8                   2         51.0              30.02

# %%
data[data['Experience_Years']<0]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Education, Experience_Years, Department, Job_Level, Performance_Rating, Certifications, Overtime_Hours, Remote_Work, City, Company_Tenure, Projects_Completed, Skill_Score, Annual_Salary_LPA]
# Index: []

# %%
data[data['Skill_Score']>100]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Education, Experience_Years, Department, Job_Level, Performance_Rating, Certifications, Overtime_Hours, Remote_Work, City, Company_Tenure, Projects_Completed, Skill_Score, Annual_Salary_LPA]
# Index: []

# %%
data[data['Performance_Rating']>5]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Education, Experience_Years, Department, Job_Level, Performance_Rating, Certifications, Overtime_Hours, Remote_Work, City, Company_Tenure, Projects_Completed, Skill_Score, Annual_Salary_LPA]
# Index: []

# %%
data.loc[(data['Age']<18) | (data['Age']>70),'Age']=np.nan

# %%
data.loc[(data['Experience_Years']<0),'Experience_Years']=np.nan

# %%
data.loc[(data['Skill_Score']>100),'Skill_Score']=np.nan

# %%
data.loc[(data['Performance_Rating']<18) | (data['Performance_Rating']>70),'Perfromance_Rating']=np.nan

# %%
data.isnull().sum()
# Out:
# Age                     66
# Gender                   0
# Education                0
# Experience_Years        60
# Department               0
# Job_Level                0
# Performance_Rating       0
# Certifications           0
# Overtime_Hours           0
# Remote_Work              0
# City                     0
# Company_Tenure           0
# Projects_Completed       0
# Skill_Score             60
# Annual_Salary_LPA        0
# Perfromance_Rating    5020
# dtype: int64

# %%
data.fillna({'Age':data['Age'].median()},inplace=True)
data.fillna({'Experience_Years':data['Experience_Years'].median()},inplace=True)
data.fillna({'Skill_Score':data['Skill_Score'].median()},inplace=True)
data.fillna({'Performance_Rating':data['Performance_Rating'].median()},inplace=True)
# Out:
#        Age  Gender Education  Experience_Years  Department Job_Level  \
# 0     28.0    Male    Master               6.0  Operations    Junior
# 1     26.0  Female  Bachelor               5.0  Operations    Junior
# 2     31.0  Female  Bachelor               5.0   Marketing    Junior
# 3     59.0  Female  Bachelor              29.0       Sales      Lead
# 4     23.0  Female  Bachelor               0.0       Sales    Junior
# ...    ...     ...       ...               ...         ...       ...
# 5015  25.0  Female       PhD               4.0  Operations    Junior
# 5016  21.0    Male  Bachelor               0.0   Marketing    Junior
# 5017  60.0  Female    Master              25.0          IT      Lead
# 5018  32.0    Male   Diploma              10.0          HR       Mid
# 5019  33.0    Male  Bachelor               3.0   Marketing    Junior
#
#       Performance_Rating  Certifications  Overtime_Hours Remote_Work  \
# ...

# %%
data.isnull().sum()
# Out:
# Age                      0
# Gender                   0
# Education                0
# Experience_Years         0
# Department               0
# Job_Level                0
# Performance_Rating       0
# Certifications           0
# Overtime_Hours           0
# Remote_Work              0
# City                     0
# Company_Tenure           0
# Projects_Completed       0
# Skill_Score              0
# Annual_Salary_LPA        0
# Perfromance_Rating    5020
# dtype: int64

# %%
plt.figure(figsize=(15,8))
for i,col in enumerate(numerical_cols,1):
    plt.subplot(3,4,i)
    sns.boxplot(y=data[col])
plt.tight_layout()
plt.show()

# %%
def remove_outliers(data,column):
    Q1=data[column].quantile(0.25)
    Q3=data[column].quantile(0.750)
    IQR=Q3-Q1
    lower=Q1-1.15*IQR
    upper=Q3+1.5*IQR
    return data[(data[column]>=lower) & (data[column]<=upper)]

# %%
for col in numerical_cols:
    if col !='Annual_Salary_LPA':
        data=remove_outliers(data,col)

# %%
data['Annual_Salary_LPA'].describe()
# Out:
# count    5020.000000
# mean       46.361203
# std        14.427832
# min        15.530000
# 25%        35.530000
# 50%        45.085000
# 75%        55.560000
# max       184.190000
# Name: Annual_Salary_LPA, dtype: float64

# %%
data.shape
# Out:
# (5020, 16)

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data.corr(numeric_only=True),annot=True,cmap='coolwarm')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data['Gender']=le.fit_transform(data['Gender'])
data['Remote_Work']=le.fit_transform(data['Remote_Work'])

# %%
data['Job_Level'].unique()
# Out:
# <ArrowStringArray>
# ['Junior', 'Lead', 'Mid', 'Senior', 'Manager']
# Length: 5, dtype: str

# %%
job_mapping={'Junior':1,'Mid':2,'Senior':3,'Lead':4,'Manager':5}
data['Job_Level']=data['Job_Level'].map(job_mapping)

# %%
#df=pd.get_dummies(df,columns=['Education','Departments','City'],drop_first=True,dtype=int

# %%
data['Education'].unique()
# Out:
# <ArrowStringArray>
# ['Master', 'Bachelor', 'Diploma', 'PhD']
# Length: 4, dtype: str

# %%
data['Department'].unique()
# Out:
# <ArrowStringArray>
# ['Operations', 'Marketing', 'Sales', 'IT', 'HR']
# Length: 5, dtype: str

# %%
data['City'].unique()
# Out:
# <ArrowStringArray>
# ['Chennai', 'Delhi', 'Hyderabad', 'Mumbai']
# Length: 4, dtype: str

# %%
data['Education']=data['Education'].map({'Diploma':0,'Bachelor':1,'Master':2,'PhD':3})
data['Department']=data['Department'].map({'Operations':0,'IT':1,'Sales':2,'HR':3,'Marketing':4})
data['City']=data['City'].map({'Chennai':0,'Delhi':1,'Hyderabad':2,'Mumbai':3})

# %%
X=data.drop('Annual_Salary_LPA',axis=1)
y=data['Annual_Salary_LPA']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X
# Out:
#        Age  Gender  Education  Experience_Years  Department  Job_Level  \
# 0     28.0       1          2               6.0           0          1
# 1     26.0       0          1               5.0           0          1
# 2     31.0       0          1               5.0           4          1
# 3     59.0       0          1              29.0           2          4
# 4     23.0       0          1               0.0           2          1
# ...    ...     ...        ...               ...         ...        ...
# 5015  25.0       0          3               4.0           0          1
# 5016  21.0       1          1               0.0           4          1
# 5017  60.0       0          2              25.0           1          4
# 5018  32.0       1          0              10.0           3          2
# 5019  33.0       1          1               3.0           4          1
#
#       Performance_Rating  Certifications  Overtime_Hours  Remote_Work  City  \
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

lr = LinearRegression()
rf = RandomForestRegressor()
gbr = GradientBoostingRegressor()
xg = XGBRegressor()

lr.fit(X_train, y_train)
rf.fit(X_train, y_train)
gbr.fit(X_train, y_train)
xg.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 11
#       7 rf = RandomForestRegressor()
#       8 gbr = GradientBoostingRegressor()
#       9 xg = XGBRegressor()
#      10
# ---> 11 lr.fit(X_train, y_train)
#      12 rf.fit(X_train, y_train)
#      13 gbr.fit(X_train, y_train)
#      14 xg.fit(X_train, y_train)
#
# File ~\OneDrive\Desktop\Batch 2\venv\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = rf.predict(X_test)
y_pred3 = gbr.predict(X_test)
y_pred4 = xg.predict(X_test)

# %%
from sklearn.metrics import (mean_absolute_error,mean_squared_error,r2_score)
import numpy as np

score1 = r2_score(y_test, y_pred1)
score2 = r2_score(y_test,y_pred2)
score3 = r2_score(y_test,y_pred3)
score4 = r2_score(y_test,y_pred4)

print("R² Score :", score1)
print("R² Score :", score2)
print("R² Score :", score3)
print("R² Score :", score4)

# %%
import pandas as pd

comparison = pd.DataFrame({'Actual Salary': y_test.values,'Predicted Salary': y_pred1})

comparison.head(10)

# %%
df.head(1)

# %%
new_employee = pd.DataFrame({
    'Age': [28],
    'Gender': [1],
    'Education':[2],
    'Experience_Years': [6],
    'Department': [0],
    'Job_Level': [1],
    'Performance_Rating': [1],
    'Certifications': [4],
    'Overtime_Hours': [15],
    'Remote_Work': [1],
    'City': [3],
    'Company_Tenure': [6],
    'Projects_Completed': [5],
    'Skill_Score': [97]
})

# %%
new_employee_scaled = scaler.transform(new_employee)

# %%
predicted_salary = lr.predict(new_employee_scaled)

print(f"Predicted Salary: {predicted_salary[0]:.2f} LPA")

# %%
gbr = GradientBoostingRegressor() 
xg_final = gbr.fit(X,y)

# %%
import joblib
joblib.dump(xg_final,'xgb_model.pkl')

# %%
['xgb_model.pkl']
